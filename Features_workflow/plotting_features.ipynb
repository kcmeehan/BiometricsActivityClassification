# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
feature_df = pd.read_csv('Test_feature_df.csv')

# %%
feature_df.head()
# Out:
#    timestamp_mean  activityID_mean  heart_rate_mean  hand_temp_mean  \
# 0          50.215              1.0       103.951172       30.523682
# 1          55.345              1.0       106.669922       30.571167
# 2          60.475              1.0       104.689453       30.625000
# 3          65.605              1.0       101.376953       30.667236
# 4          70.735              1.0        97.681641       30.694580
#
#    hand_acc16g_x_mean  hand_acc16g_y_mean  hand_acc16g_z_mean  \
# 0           -1.879247            4.788385            6.990495
# 1            0.391882            5.722934            7.994521
# 2            6.146379            4.694468            5.897999
# 3            6.106217            4.933678            5.845775
# 4            6.087676            4.997965            5.825435
#
#    hand_gyro_x_mean  hand_gyro_y_mean  hand_gyro_z_mean        ...          \
# 0          0.107901         -0.251155          0.211265        ...
# 1         -0.016516         -0.033348          0.076686        ...
# 2          0.109086          0.003930          0.086883        ...
# 3          0.004890          0.002275         -0.007698        ...
# 4          0.002996          0.007227         -0.006835        ...
#
#    chest_gyro_x_peak  chest_gyro_y_peak  chest_gyro_z_peak  ankle_temp_peak  \
# 0           2.262240           0.875723           1.051120          30.9375
# 1           0.266649           0.208297           0.270963          31.0000
# 2           0.099364           0.128430           0.086655          31.0000
# 3           0.093799           0.115173           0.058769          31.0625
# 4           0.072826           0.110935           0.071166          31.1250
#
#    ankle_acc16g_x_peak  ankle_acc16g_y_peak  ankle_acc16g_z_peak  \
# 0            15.252700             29.71820             12.87120
# 1             0.796365              8.45641              6.37917
# 2             0.811769              8.18447              6.64932
# 3             0.841604              8.03427              6.68939
# 4             0.810582              7.99476              6.72800
#
#    ankle_gyro_x_peak  ankle_gyro_y_peak  ankle_gyro_z_peak
# 0           2.609650           1.813310           3.461520
# 1           0.163835           0.077943           0.091133
# 2           0.097425           0.080968           0.058141
# 3           0.069279           0.077147           0.045535
# 4           0.084190           0.066471           0.058728
#
# [5 rows x 91 columns]

# %%
#dictionary converting activity id to activity name#dictiona 
activity_dict={0:'other',1:'lying',2:'sitting',3:'standing',4:'walking',5:'running',6:'cycling',7:'nordic walking',
              9:'watching TV',10:'computer work',11:'car driving',12:'ascending stairs',13:'descending stairs',
              16:'vacuum cleaning',17:'ironing',18:'folding laundry',19:'house cleaning',20:'playing_soccer',
              24:'rope jumping'}

# %%
feature_plot = 'heart_rate'

# %%
activities_to_plot=[2,9,10,5,6,11,12]
features_to_plot=['mean','median','std','peak']

# %% [markdown]
# Need one plot per unique combination pair

# %%
from plotting_tools import plot_feature_distributions

# %%
fig = plot_feature_distributions('heart_rate',features_to_plot,activities_to_plot,data=feature_df)

# %%
fig = plot_feature_distributions('hand_acc16g_x',features_to_plot,activities_to_plot,data=feature_df)

# %%
fig = plt.figure(figsize=(20,30))
ax1 = fig.add_subplot(411)
sns.boxplot(y=feature_df['heart_rate_mean'],x=feature_df['activityID_mean'],palette='Paired')
ax1 = fig.add_subplot(412)
sns.boxplot(y=feature_df['heart_rate_median'],x=feature_df['activityID_mean'],palette='Paired')
ax1 = fig.add_subplot(413)
sns.boxplot(y=feature_df['heart_rate_std'],x=feature_df['activityID_mean'],palette='Paired')
ax1 = fig.add_subplot(414)
sns.boxplot(y=feature_df['heart_rate_peak'],x=feature_df['activityID_mean'],palette='Paired')
