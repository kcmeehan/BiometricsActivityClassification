# %% [markdown]
# ### Testing on full dataset

# %%
import DataProcess as DP
import glob
import time
import pandas as pd
from plotting_tools import plot_feature_distributions

# %%
protocol_datadir = '/Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Protocol/'
optional_datadir = '/Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Optional/'

# %%
allfiles = list(glob.glob(protocol_datadir+'*.dat'))+list(glob.glob(optional_datadir+'*.dat'))

# %% [markdown]
# #### Load all the data and combine the result into a single dataframe

# %%
start = time.time()
all_dfs = []
for fname in allfiles:
    print(fname)
    dp = DP.dataprocess(fname)
    all_dfs.append(dp.df)

feature_df = pd.concat(all_dfs)
end = time.time()
# Out:
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Protocol/subject101.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Protocol/subject102.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Protocol/subject103.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Protocol/subject104.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Protocol/subject105.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Protocol/subject106.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Protocol/subject107.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Protocol/subject108.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Protocol/subject109.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Optional/subject101.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Optional/subject105.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Optional/subject106.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Optional/subject108.dat
# /Users/rmartinshort/Documents/Berkeley/GDSO/PAMAP2_data/PAMAP2_Dataset/Optional/subject109.dat

# %%
print(end-start)
# Out:
# 110.75403785705566

# %% [markdown]
# Pretty fast! Considering this includes time taken to load the data too

# %% [markdown]
# #### Test plotting functionality

# %%
feature_df.head()
# Out:
#    heart_rate_mean  hand_temp_mean  hand_acc16g_x_mean  hand_acc16g_y_mean  \
# 0        94.348848       30.523682           -1.879247            4.788385
# 1        97.572166       30.571045            0.385014            5.728775
# 2        95.238678       30.625000            6.138466            4.687556
# 3        91.322497       30.666870            6.105873            4.933169
# 4        86.938228       30.694580            6.088404            4.999214
#
#    hand_acc16g_z_mean  hand_gyro_x_mean  hand_gyro_y_mean  hand_gyro_z_mean  \
# 0            6.990495          0.107901         -0.251155          0.211265
# 1            7.995225         -0.015914         -0.031787          0.073627
# 2            5.905270          0.108601          0.000832          0.093104
# 3            5.846599          0.004938          0.002278         -0.007819
# 4            5.824916          0.003294          0.007085         -0.006836
#
#    hand_mag_x_mean  hand_mag_y_mean     ...      ankle_gyro_x_peak  \
# 0       -20.487241        23.732523     ...               2.609650
# 1       -30.979146        18.440913     ...               0.163835
# 2       -14.850929        17.169063     ...               0.097425
# 3       -13.701133        15.525804     ...               0.069279
# 4       -13.684949        15.127545     ...               0.084190
#
#    ankle_gyro_y_peak  ankle_gyro_z_peak  ankle_mag_x_peak  ankle_mag_y_peak  \
# 0           1.813310           3.461520          117.2680           46.5085
# 1           0.077943           0.091133           15.8144           45.6696
# 2           0.080968           0.058141           15.5624           46.0851
# 3           0.077147           0.045535           15.6788           46.0951
# 4           0.066471           0.058728           15.6844           45.9978
#
#    ankle_mag_z_peak  hand_acc_vsum_welch  chest_acc_vsum_welch  \
# 0          54.10840             2.343750             10.937500
# 1          11.47720             0.390625              5.078125
# 2           8.62547             0.000000              6.640625
# 3           8.25636            30.078125             10.546875
# 4           8.00118            26.562500             10.546875
#
#    ankle_acc_vsum_welch  activityID
# 0              1.171875         1.0
# 1             16.796875         1.0
# 2              6.640625         1.0
# 3             45.703125         1.0
# 4             33.984375         1.0
#
# [5 rows x 128 columns]

# %%
activities_to_plot=[2,9,10,5,6,11,12]
features_to_plot=['mean','median','std','peak']

# %%
fig = plot_feature_distributions('heart_rate',features_to_plot,activities_to_plot,data=feature_df)

# %%
activities_to_plot = [5,2]
features_to_plot = ['acc_vsum_welch']
fig = plot_feature_distributions('ankle',features_to_plot,activities_to_plot,data=feature_df)
